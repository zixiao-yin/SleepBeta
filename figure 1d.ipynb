# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import yasa

# %%
data = np.load(r'C:\Users\Lenovo\1代码 REM中beta升高\upload_data\figure1d_data.npy')
hypno = np.load(r'C:\Users\Lenovo\1代码 REM中beta升高\upload_data\figure1d_hypno.npy')
sf = 100

# %%
fig = yasa.plot_spectrogram(data, sf, hypno,  fmin = 3, fmax = 40)
